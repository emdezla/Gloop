# %%
from data_curation import*

# %%
dataset = DiabetesDataset("datasets/processed/563-train.csv")
evaluate_dataset_coverage(dataset)
# Out:
# === Coverage Metrics ===
#
# State Ranges:
#            glu     glu_d     glu_t        hr      hr_d      hr_t       iob  \
# min  -2.134330 -4.408866 -5.182292 -2.093450 -6.559240 -5.330500 -1.054049
# max   5.110807  7.273521  3.317983  4.119766  6.854393  4.775674  5.054017
# mean  0.014598  0.024049  0.014231 -0.004595  0.090159  0.109993  0.007914
# std   0.985235  1.055674  1.105011  0.939318  1.002523  0.990678  0.974530
#
#           hour
# min   0.000000
# max   0.958333
# mean  0.485875
# std   0.286724
#
# Action Coverage:
#         basal     bolus
# min  -0.40000 -1.000000
# max   0.60000  0.480000
# mean -0.15870 -0.979844
# std   0.24616  0.132365
#
# Reward Statistics:
#           count  mean  std  min  25%  50%  75%  max
# reward  13247.0  -5.0  0.0 -5.0 -5.0 -5.0 -5.0 -5.0
#
# Missing States: 0
# Missing Actions: 0
#
# Top State-Action Correlations:
# basal    1.0
# bolus    1.0
# dtype: float64
